# %%
import torch
import torch.nn as nn

# %%
linear = nn.Linear(in_features=5, out_features=10)

# %%
# 定义三维张量输入，N = 100，L = 25
input = torch.randn(100, 25, 5)
# 前向传播
output = linear(input)
print(output.shape)
# Out:
# torch.Size([100, 25, 10])
